# %%
import rqdatac
import pandas as pd
import statsmodels.api as sm
from linearmodels.panel import FamaMacBeth
import csv
import numpy as np
import import_ipynb
import a_general_factor_test
rqdatac.init()
start_date = pd.to_datetime('2018-01-01')
end_date = pd.to_datetime('2020-12-31')
instrument_type = 'Convertible'
factor_name = '第二产业增加值占GDP比重(现价)'
remaining_time_to_mature ='短期 (1-3年)'
rolling_window = 90
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       6 import numpy as np
#       7 import import_ipynb
# ----> 8 import a_general_factor_test
#       9 rqdatac.init()
#      10 start_date = pd.to_datetime('2018-01-01')
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/import_ipynb.py:64, in NotebookLoader.exec_module(self, mod)
#      60             code = self.shell.input_transformer_manager.transform_cell(
#      61                 cell.source
#      62             )
#      63             # run the code in themodule
# ---> 64             exec(code, mod.__dict__)
#      65 finally:
#      66     self.shell.user_ns = save_user_ns
#
# File <string>:23
#
# NameError: name 'start_date' is not defined

# %%
# 读取 Excel 文件
df = pd.read_excel('a_econ_get_factors.xlsx')  # 默认读取第一个 sheet


# 提取第一列（不管列名是什么）
first_column = df.iloc[:, 0]  # 取所有行，第0列
#first_column = ['工业品出厂价格指数PPI_当月同比_(上年同月=100)','工业品出厂价格指数PPI_当月同比_(上年同月=100)','工业品出厂价格指数PPI_当月同比_(上年同月=100)']
# 输出查看
for i in first_column:
    cleaned_name = str(i).strip().strip("'").strip('"')
    a_general_factor_test.main_test_for_econ_get_factors(start_date,end_date,instrument_type,cleaned_name,remaining_time_to_mature,rolling_window)
# Out:
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 国内生产总值GDP增速(不变价)_累计值_季
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.1397
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0468
# No. Observations:                      48024   R-squared (Within):              -0.1494
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.1397
# Time:                               01:08:53   Log-likelihood                 3.885e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -5884.9
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.36   Distribution:                 F(1,48022)
# Min Obs:                              2.0000
# Max Obs:                              622.00   F-statistic (robust):             2.0077
#                                                P-value                           0.1565
# Time periods:                            622   Distribution:                 F(1,48022)
# Avg Obs:                              77.209
# Min Obs:                              24.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0159     0.0013     12.398     0.0000      0.0134      0.0184
# beta          -0.4864     0.3433    -1.4169     0.1565     -1.1592      0.1864
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民消费价格指数CPI_(上年=100)_累计
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.0064
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0032
# No. Observations:                      48155   R-squared (Within):              -0.0079
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.0064
# Time:                               01:09:38   Log-likelihood                 4.199e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -307.67
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             2.3271
#                                                P-value                           0.1271
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0168     0.0014     12.384     0.0000      0.0141      0.0194
# beta          -0.3363     0.2204    -1.5255     0.1271     -0.7684      0.0958
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民消费价格指数CPI_(上月=100)_当月
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.0004
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0124
# No. Observations:                      48155   R-squared (Within):              -0.0003
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.0004
# Time:                               01:10:23   Log-likelihood                 4.213e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -18.536
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             0.0369
#                                                P-value                           0.8477
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0170     0.0014     11.978     0.0000      0.0142      0.0198
# beta           0.0874     0.4551     0.1921     0.8477     -0.8045      0.9793
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民消费价格指数CPI_(上年=100)_当月
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                        0.0019
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0126
# No. Observations:                      48155   R-squared (Within):               0.0030
# Date:                       Fri, Jul 18 2025   R-squared (Overall):              0.0019
# Time:                               01:11:08   Log-likelihood                 4.219e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                      91.536
# Entities:                                235   P-value                           0.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             0.4422
#                                                P-value                           0.5061
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0179     0.0014     12.767     0.0000      0.0151      0.0206
# beta           0.1975     0.2970     0.6650     0.5061     -0.3846      0.7795
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 工业品出厂价格指数PPI_(上年=100)_当月
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                        0.0010
# Estimator:                       FamaMacBeth   R-squared (Between):              0.0078
# No. Observations:                      48155   R-squared (Within):              -0.0007
# Date:                       Fri, Jul 18 2025   R-squared (Overall):              0.0010
# Time:                               01:11:51   Log-likelihood                 4.217e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                      48.606
# Entities:                                235   P-value                           0.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             9.8702
#                                                P-value                           0.0017
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0176     0.0014     12.462     0.0000      0.0149      0.0204
# beta           0.5346     0.1702     3.1417     0.0017      0.2011      0.8681
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民肉禽及其制品消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民蛋类消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民粮食消费价格指数CPI_(上年=100)_累计
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.0102
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0017
# No. Observations:                      48155   R-squared (Within):              -0.0155
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.0102
# Time:                               01:12:37   Log-likelihood                  4.19e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -487.69
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             6.1200
#                                                P-value                           0.0134
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0170     0.0014     12.157     0.0000      0.0143      0.0198
# beta           0.3973     0.1606     2.4739     0.0134      0.0825      0.7121
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民肉禽及其制品消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农村居民肉禽及其制品消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农村居民蛋类消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民蛋类消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民粮食消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农村居民粮食消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农村居民鲜菜消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民水产品消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民鲜菜消费价格指数CPI_(上年=100)_累计
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.0008
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0126
# No. Observations:                      48155   R-squared (Within):              -0.0009
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.0008
# Time:                               01:13:32   Log-likelihood                 4.212e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -38.049
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             0.0591
#                                                P-value                           0.8079
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0155     0.0013     11.753     0.0000      0.0129      0.0181
# beta           0.0786     0.3233     0.2431     0.8079     -0.5551      0.7122
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民水产品消费价格指数CPI_(上年=100)_累计
#                              FamaMacBeth Estimation Summary
# =======================================================================================
# Dep. Variable:                     return_30   R-squared:                       -0.0001
# Estimator:                       FamaMacBeth   R-squared (Between):             -0.0095
# No. Observations:                      48155   R-squared (Within):              -0.0002
# Date:                       Fri, Jul 18 2025   R-squared (Overall):             -0.0001
# Time:                               01:14:17   Log-likelihood                 4.214e+04
# Cov. Estimator:    Fama-MacBeth Standard Cov
#                                                F-statistic:                     -5.9975
# Entities:                                235   P-value                           1.0000
# Avg Obs:                              204.91   Distribution:                 F(1,48153)
# Min Obs:                              2.0000
# Max Obs:                              628.00   F-statistic (robust):             0.0166
#                                                P-value                           0.8974
# Time periods:                            628   Distribution:                 F(1,48153)
# Avg Obs:                              76.680
# Min Obs:                              21.000
# Max Obs:                              131.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0161     0.0014     11.525     0.0000      0.0133      0.0188
# beta          -0.0216     0.1673    -0.1289     0.8974     -0.3496      0.3064
# ==============================================================================
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民鲜菜消费价格指数CPI_(上年=100)_累计
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 居民水电燃料消费价格指数CPI_(上月=100)_当月
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 城市居民租房消费价格指数CPI_(上月=100)_当月
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农村居民租房消费价格指数CPI_(上月=100)_当月
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 木材及纸浆类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 工业品购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 有色金属材料类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 农副产品类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 其它工业原材料及半成品类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 建筑材料类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 纺织原料类购进价格指数PPIRM(上年=100)_累计同比
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:218: UserWarning: rqdatac is already inited. Settings will be changed.
#   warnings.warn("rqdatac is already inited. Settings will be changed.", stacklevel=0)
# /opt/anaconda3/envs/rqsdk/lib/python3.9/site-packages/rqdatac/client.py:257: UserWarning: Your account will be expired after  28 days. Please call us at 0755-22676337 to upgrade or purchase or renew your contract.
#   warnings.warn("Your account will be expired after  {} days. "
# 可转债数量: 449
# testing: 工业品出厂价格指数PPI(上年=100)_累计同比
